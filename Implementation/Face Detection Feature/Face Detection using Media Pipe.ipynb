# %% [markdown]
# MediaPipe Face Detection

# %%
import time
import cv2
import mediapipe as mp
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# %%
# For WebCam input
FPS = []
cap = cv2.VideoCapture(0)
img_num = 1
with mp_face_detection.FaceDetection(
    model_selection=0, # 
    min_detection_confidence=0.5) as face_detection: # Take a value that performs such that faces outside 1 m are detected are less detected
    while cap.isOpened():
        init = time.time()
        success,image = cap.read()
        if not success:
            print("No Camera Detected")
            break
        print(f'Detection of Image {img_num}')
        image.flags.writeable = False
        # image  = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        results = face_detection.process(image)
        image.flags.writeable = True
        # print(results.detections)
        if results.detections:
            if len(results.detections)>1:
                print(f"Multiple Faces Detected: {len(results.detections)}")
            for detection in results.detections:
                mp_drawing.draw_detection(image,detection)
        else:
            print("No Face Detected")
            # break
        img_num+=1
        cv2.imshow('MediaPipe Face Detection', cv2.flip(image, 1))
        if cv2.waitKey(1) & 0xFF==ord('q'): break
        fps = (1)/(time.time() - init)
        print('Fps: {}'.format(fps))
        FPS.append(fps)
    cap.release()
    cv2.destroyAllWindows()
    print("Range: "+str(min(FPS))+"fps - "+str(max(FPS))+" fps")
    print("Mean FPS: "+str(sum(FPS)/len(FPS))+" fps")
# Out:
# Detection of Image 1
# Fps: 1.5704351257736004
# Detection of Image 2
# Fps: 77.11109885463203
# Detection of Image 3
# Fps: 77.14230012322746
# Detection of Image 4
# Fps: 91.13495426199944
# Detection of Image 5
# Fps: 83.29468771720782
# Detection of Image 6
# Fps: 59.12383529975614
# Detection of Image 7
# Fps: 37.300274796126175
# Detection of Image 8
# Fps: 27.85506322388694
# Detection of Image 9
# Fps: 33.434602385051974
# Detection of Image 10
# Fps: 16.172307027927403
# Detection of Image 11
# Fps: 31.333746703620974
# Detection of Image 12
# Fps: 31.333512625130734
# Detection of Image 13
# Fps: 32.04327132434394
# Detection of Image 14
# Fps: 32.91612255148167
# Detection of Image 15
# Fps: 31.968780487804878
# Detection of Image 16
# Fps: 32.55688892338741
# Detection of Image 17
# Fps: 33.01639679778332
# Detection of Image 18
# Fps: 30.120891352900202
# Detection of Image 19
# Fps: 41.73229192577484
# Detection of Image 20
# Fps: 31.46207796688995
# Detection of Image 21
# Fps: 30.893398248469804
# Detection of Image 22
# Fps: 31.964882331423
# Detection of Image 23
# Fps: 32.85527181576062
# Detection of Image 24
# Fps: 31.083193763061555
# Detection of Image 25
# Fps: 33.7618648979329
# Detection of Image 26
# Fps: 14.764413091994564
# Detection of Image 27
# Fps: 34.33001571503405
# Detection of Image 28
# Fps: 31.154304389809106
# Detection of Image 29
# Fps: 20.51205007824726
# Detection of Image 30
# Fps: 26.97579172133467
# Detection of Image 31
# Fps: 95.42485325567638
# Detection of Image 32
# Fps: 44.33350245222391
# Detection of Image 33
# Fps: 37.83151134682686
# Detection of Image 34
# Fps: 34.075653191212794
# Detection of Image 35
# Fps: 30.024295439415305
# Detection of Image 36
# Fps: 34.054626351856065
# Detection of Image 37
# Fps: 30.012908765652952
# Detection of Image 38
# Fps: 15.367747655983791
# Detection of Image 39
# Fps: 30.584772891342233
# Detection of Image 40
# Fps: 34.610752155794856
# Detection of Image 41
# Fps: 31.476244437273458
# Detection of Image 42
# Fps: 31.64079662039831
# Detection of Image 43
# Fps: 31.12910144798462
# Detection of Image 44
# Fps: 30.988348811608336
# Detection of Image 45
# Fps: 30.740338456351736
# Detection of Image 46
# Fps: 33.58775104904065
# Detection of Image 47
# Fps: 32.292940569589554
# Detection of Image 48
# Fps: 20.43280899095351
# Detection of Image 49
# Fps: 27.54173971856142
# Detection of Image 50
# Fps: 34.08229864135734
# Detection of Image 51
# Fps: 32.792594445834375
# Detection of Image 52
# Fps: 29.87183249056335
# Detection of Image 53
# Fps: 32.626025809563075
# Detection of Image 54
# Fps: 35.82150330090786
# Detection of Image 55
# Fps: 26.449469661617627
# Detection of Image 56
# Fps: 31.240393567656543
# Detection of Image 57
# Fps: 27.66545301039523
# Detection of Image 58
# Fps: 24.695037799392384
# Detection of Image 59
# Fps: 42.60469084888315
# Detection of Image 60
# Fps: 35.330570437009335
# Detection of Image 61
# Fps: 34.68172684951669
# Detection of Image 62
# Fps: 26.410331647912955
# Detection of Image 63
# Fps: 40.180328968166535
# Detection of Image 64
# Fps: 31.018140673416113
# Detection of Image 65
# Fps: 35.79521228931086
# Detection of Image 66
# Fps: 30.482081991874942
# Detection of Image 67
# Fps: 32.642784319524324
# Detection of Image 68
# Fps: 21.190738186539754
# Detection of Image 69
# Fps: 31.379224179852617
# Detection of Image 70
# Fps: 22.34019185393109
# Detection of Image 71
# Fps: 33.158650349429216
# Detection of Image 72
# Fps: 52.5391321775729
# Detection of Image 73
# Fps: 21.345384407904447
# Detection of Image 74
# Fps: 50.2209610019517
# Detection of Image 75
# Fps: 21.52415261847946
# Detection of Image 76
# Fps: 63.77326704070307
# Detection of Image 77
# Fps: 30.355233256618465
# Detection of Image 78
# Fps: 22.30336546898015
# Detection of Image 79
# Fps: 31.662293349437608
# Detection of Image 80
# Fps: 30.936692801876426
# Detection of Image 81
# Fps: 31.12078649601187
# Detection of Image 82
# Fps: 54.611911148147186
# Detection of Image 83
# Fps: 21.66591249548014
# Detection of Image 84
# Fps: 43.51705176224023
# Detection of Image 85
# Fps: 38.86169611503859
# Detection of Image 86
# Fps: 11.521515433701149
# Detection of Image 87
# Fps: 30.150771685919878
# Detection of Image 88
# Fps: 63.72191668439124
# Detection of Image 89
# Fps: 56.8580414271771
# Detection of Image 90
# Fps: 32.4242522631168
# Detection of Image 91
# Fps: 32.71509355963403
# Detection of Image 92
# Fps: 42.40139912453623
# Detection of Image 93
# Fps: 26.52876587562617
# Detection of Image 94
# Fps: 38.1341964577954
# Detection of Image 95
# Fps: 21.139366570570328
# Detection of Image 96
# Fps: 33.618980442449505
# Detection of Image 97
# Fps: 32.609284498106874
# Detection of Image 98
# Fps: 16.018943299953406
# Detection of Image 99
# Fps: 32.03641835277224
# Detection of Image 100
# Fps: 32.42851399412402
# Detection of Image 101
# Fps: 32.67380753920339
# Detection of Image 102
# Fps: 32.45335458561912
# Detection of Image 103
# Fps: 25.884853459395078
# Detection of Image 104
# Fps: 32.91870595068046
# Detection of Image 105
# Fps: 42.178395446591985
# Detection of Image 106
# Fps: 18.495605737896486
# Detection of Image 107
# Fps: 33.3824456400624
# Detection of Image 108
# Fps: 62.78146329780864
# Detection of Image 109
# Fps: 63.7044957472661
# Detection of Image 110
# Fps: 15.807459947161535
# Detection of Image 111
# Fps: 23.3918775724181
# Detection of Image 112
# Fps: 45.57936145704288
# Detection of Image 113
# Fps: 29.490624011249782
# Detection of Image 114
# Fps: 41.778432974082115
# Detection of Image 115
# Fps: 27.852843520068
# Detection of Image 116
# Fps: 35.585359645699356
# Detection of Image 117
# Fps: 27.081691159379115
# Detection of Image 118
# Fps: 27.237685808726596
# Detection of Image 119
# Fps: 32.271075855383124
# Detection of Image 120
# Fps: 44.4293038430575
# Detection of Image 121
# Fps: 24.816017418469258
# Detection of Image 122
# Fps: 32.15701668302257
# Detection of Image 123
# Fps: 22.653423421963694
# Detection of Image 124
# Fps: 84.19254084868923
# Detection of Image 125
# Fps: 21.871191460737435
# Detection of Image 126
# Fps: 20.40745786462185
# Detection of Image 127
# Fps: 34.960399423203555
# Detection of Image 128
# Fps: 31.22086003736704
# Detection of Image 129
# Fps: 74.86085528664239
# Detection of Image 130
# Fps: 29.65870215459026
# Detection of Image 131
# Fps: 33.78198746758163
# Detection of Image 132
# Fps: 30.249929681583787
# Detection of Image 133
# Fps: 30.32100050603629
# Detection of Image 134
# Fps: 27.097962954588038
# Detection of Image 135
# Fps: 30.63145594765132
# Detection of Image 136
# Fps: 22.278132469325968
# Detection of Image 137
# Fps: 32.140014252764345
# Detection of Image 138
# Fps: 32.18267755202259
# Detection of Image 139
# Fps: 62.799323241851205
# Detection of Image 140
# Fps: 31.30965497678446
# Detection of Image 141
# Fps: 30.28181562208954
# Detection of Image 142
# Fps: 22.344000213088993
# Detection of Image 143
# Fps: 67.15614192391443
# Detection of Image 144
# Fps: 21.494040115200526
# Detection of Image 145
# Fps: 29.130752455168007
# Detection of Image 146
# Fps: 31.19369329168526
# Detection of Image 147
# Fps: 23.59186887606448
# Detection of Image 148
# Fps: 42.332498990714576
# Detection of Image 149
# Fps: 29.746625910454537
# Detection of Image 150
# Fps: 32.52911431673647
# Detection of Image 151
# Fps: 33.593131287242905
# Detection of Image 152
# Fps: 30.924831710032514
# Detection of Image 153
# Fps: 28.162733077733986
# Detection of Image 154
# Fps: 32.50340199314952
# Detection of Image 155
# Fps: 28.369603300754168
# Detection of Image 156
# Fps: 25.039126022327025
# Detection of Image 157
# Fps: 30.913435387937707
# Detection of Image 158
# Fps: 15.273230451026517
# Detection of Image 159
# Fps: 32.89598594531851
# Detection of Image 160
# Fps: 32.95931854436298
# Detection of Image 161
# Fps: 29.13034781642405
# Detection of Image 162
# Fps: 32.87278199260142
# Detection of Image 163
# Fps: 23.380793908278566
# Detection of Image 164
# Fps: 28.483850813571294
# Detection of Image 165
# Fps: 50.64544719079416
# Detection of Image 166
# Fps: 79.78816009739765
# Detection of Image 167
# Fps: 46.63965306349383
# Detection of Image 168
# Fps: 29.816196542311193
# Detection of Image 169
# Fps: 27.38368327588008
# Detection of Image 170
# Fps: 15.717009413034354
# Detection of Image 171
# Fps: 0.7289612846029474
# Detection of Image 172
# Fps: 124.83047619047619
# Detection of Image 173
# Fps: 63.47312348668281
# Detection of Image 174
# Fps: 63.511568746214415
# Detection of Image 175
# Fps: 72.04850983423516
# Detection of Image 176
# Fps: 20.685746413300258
# Detection of Image 177
# Fps: 66.58788042356602
# Detection of Image 178
# Fps: 21.226127398140697
# Detection of Image 179
# Fps: 19.377882909520995
# Detection of Image 180
# Fps: 30.790436129524817
# Detection of Image 181
# Fps: 27.738638167292734
# Detection of Image 182
# Fps: 21.928478815508804
# Detection of Image 183
# Fps: 31.272537484808495
# Detection of Image 184
# Fps: 94.9668070461441
# Detection of Image 185
# Fps: 49.820095261851314
# Detection of Image 186
# Fps: 30.355233256618465
# Detection of Image 187
# Fps: 31.252498006810374
# Detection of Image 188
# Fps: 28.853007539485994
# Detection of Image 189
# Fps: 32.109012684973244
# Detection of Image 190
# Fps: 33.878034990226645
# Detection of Image 191
# Fps: 15.75573987258084
# Detection of Image 192
# Fps: 32.307118758954296
# Detection of Image 193
# Fps: 29.924046659294405
# Detection of Image 194
# Fps: 30.34513095065837
# Detection of Image 195
# Fps: 31.17190124411017
# Detection of Image 196
# Fps: 31.199958343561477
# Detection of Image 197
# Fps: 31.8723375152929
# Detection of Image 198
# Fps: 32.26586251461629
# Detection of Image 199
# Fps: 28.913273360217833
# Detection of Image 200
# Fps: 33.509127659404484
# Detection of Image 201
# Fps: 30.671327239488118
# Detection of Image 202
# Fps: 22.037704125596353
# Detection of Image 203
# Fps: 29.602602920521996
# Detection of Image 204
# Fps: 30.504694647883227
# Detection of Image 205
# Fps: 30.445794589258362
# Detection of Image 206
# Fps: 32.178727060700915
# Detection of Image 207
# Fps: 30.55736558356404
# Detection of Image 208
# Fps: 35.435938595676014
# Detection of Image 209
# Fps: 29.48399024301089
# Detection of Image 210
# Fps: 30.544681284910098
# Detection of Image 211
# Fps: 33.39467188967977
# Detection of Image 212
# Fps: 30.353695515302395
# Detection of Image 213
# Fps: 32.19750053735376
# Detection of Image 214
# Fps: 31.86192646611972
# Detection of Image 215
# Fps: 30.688831655350036
# Detection of Image 216
# Fps: 32.73449828690949
# Detection of Image 217
# Fps: 28.105552354021203
# Detection of Image 218
# Fps: 33.79559738292455
# Detection of Image 219
# Fps: 29.463071973475323
# Detection of Image 220
# Fps: 32.55992175006598
# Detection of Image 221
# Fps: 20.759256601252197
# Detection of Image 222
# Fps: 31.896818154164386
# Detection of Image 223
# Fps: 31.36561399310515
# Detection of Image 224
# Fps: 31.10463124327932
# Detection of Image 225
# Fps: 32.442560564338976
# Detection of Image 226
# Fps: 31.913078544309094
# Detection of Image 227
# Fps: 31.990725345130045
# Detection of Image 228
# Fps: 31.190677682508756
# Detection of Image 229
# Fps: 31.75722700910096
# Detection of Image 230
# Fps: 30.92460370124604
# Detection of Image 231
# Fps: 29.254490036478277
# Detection of Image 232
# Fps: 30.41665034990391
# Detection of Image 233
# Fps: 32.43277684557271
# Detection of Image 234
# Fps: 31.84209167792776
# Detection of Image 235
# Fps: 30.481417421258413
# Detection of Image 236
# Fps: 33.01951584333793
# Detection of Image 237
# Fps: 31.13048770531347
# Detection of Image 238
# Fps: 31.634353292555076
# Detection of Image 239
# Fps: 13.32087516316413
# Detection of Image 240
# Fps: 20.777561463736024
# Detection of Image 241
# Fps: 54.210285507489886
# Detection of Image 242
# Fps: 50.45718547746794
# Detection of Image 243
# Fps: 36.6190031343036
# Detection of Image 244
# Fps: 32.68348255682571
# Detection of Image 245
# Fps: 31.1080916709931
# Detection of Image 246
# Fps: 30.041284075119254
# Detection of Image 247
# Fps: 32.88205964439148
# Detection of Image 248
# Fps: 42.98852082650049
# Detection of Image 249
# Fps: 34.58107495321092
# Detection of Image 250
# Fps: 30.66168590498052
# Detection of Image 251
# Fps: 15.290100796529536
# Detection of Image 252
# Fps: 30.991554416013358
# Detection of Image 253
# Fps: 28.98580531022377
# Detection of Image 254
# Fps: 33.02445553753366
# Detection of Image 255
# Fps: 34.654504593826424
# Detection of Image 256
# Fps: 23.336434246544854
# Detection of Image 257
# Fps: 30.161829426146987
# Detection of Image 258
# Fps: 33.214317389927146
# Detection of Image 259
# Fps: 25.759740578784456
# Detection of Image 260
# Fps: 29.312348871339715
# Detection of Image 261
# Fps: 236.1524688925173
# Detection of Image 262
# Fps: 41.945556733404004
# Detection of Image 263
# Fps: 15.223063047368097
# Detection of Image 264
# Fps: 27.378142154974903
# Detection of Image 265
# Fps: 38.16924658967849
# Detection of Image 266
# Fps: 38.13211629725258
# Detection of Image 267
# Fps: 22.233257354890007
# Detection of Image 268
# Fps: 31.372182953737987
# Detection of Image 269
# Fps: 31.664205583488094
# Detection of Image 270
# Fps: 44.69633418584825
# Detection of Image 271
# Fps: 28.568439407149086
# Detection of Image 272
# Fps: 33.76893225770092
# Detection of Image 273
# Fps: 29.74915773570988
# Detection of Image 274
# Fps: 30.432319479916416
# Detection of Image 275
# Fps: 29.897597103122838
# Detection of Image 276
# Fps: 32.41072242699616
# Detection of Image 277
# Fps: 30.64063059311695
# Detection of Image 278
# Fps: 31.42412754543956
# Detection of Image 279
# Fps: 21.610543779561638
# Detection of Image 280
# Fps: 33.7067866757745
# Detection of Image 281
# Fps: 31.914292671049427
# Detection of Image 282
# Fps: 32.383446571958
# Detection of Image 283
# Fps: 33.54906414973604
# Detection of Image 284
# Fps: 30.769429405636984
# Detection of Image 285
# Fps: 32.899856455952374
# Detection of Image 286
# Fps: 31.282100238663485
# Detection of Image 287
# Fps: 31.467979112898384
# Detection of Image 288
# Fps: 31.702978080120936
# Detection of Image 289
# Fps: 33.11571500757959
# Detection of Image 290
# Fps: 21.359841926218657
# Detection of Image 291
# Fps: 32.06605403587101
# Detection of Image 292
# Fps: 31.919635926393813
# Detection of Image 293
# Fps: 51.07032924215858
# Detection of Image 294
# Fps: 30.141021587283337
# Detection of Image 295
# Fps: 30.490724047688282
# Detection of Image 296
# Fps: 31.181170733157888
# Detection of Image 297
# Fps: 32.8707210031348
# Detection of Image 298
# Fps: 18.336636953033807
# Detection of Image 299
# Fps: 31.34428385669661
# Detection of Image 300
# Fps: 32.02638893130937
# Detection of Image 301
# Fps: 28.30202836745435
# Detection of Image 302
# Fps: 30.03655113148095
# Detection of Image 303
# Fps: 31.684776696682178
# Detection of Image 304
# Fps: 30.55313631363865
# Detection of Image 305
# Fps: 32.415732160660326
# Detection of Image 306
# Fps: 29.202754356771358
# Detection of Image 307
# Fps: 34.64992399709206
# Detection of Image 308
# Fps: 30.294501303710337
# Detection of Image 309
# Fps: 32.64888259241673
# Detection of Image 310
# Fps: 31.649152990001888
# Detection of Image 311
# Fps: 15.497895705317454
# Detection of Image 312
# Fps: 30.541789849268188
# Detection of Image 313
# Fps: 32.91741420039398
# Detection of Image 314
# Fps: 31.80973182866157
# Detection of Image 315
# Fps: 42.28299528206782
# Detection of Image 316
# Fps: 27.654690868811276
# Detection of Image 317
# Fps: 21.293585480390913
# Detection of Image 318
# Fps: 31.98706577693041
# Detection of Image 319
# Fps: 73.29367769894803
# Detection of Image 320
# Fps: 58.250986056330206
# Detection of Image 321
# Fps: 28.921048639554286
# Detection of Image 322
# Fps: 35.18534301964666
# Detection of Image 323
# Fps: 15.968628525959515
# Detection of Image 324
# Fps: 29.47943125830235
# Detection of Image 325
# Fps: 30.570951683321308
# Detection of Image 326
# Fps: 23.078087859846818
# Detection of Image 327
# Fps: 32.7736329681664
# Detection of Image 328
# Fps: 32.75622823047967
# Detection of Image 329
# Fps: 32.63364118045236
# Detection of Image 330
# Fps: 32.37744704501945
# Detection of Image 331
# Fps: 29.225340728559882
# Detection of Image 332
# Fps: 30.21288672789483
# Detection of Image 333
# Fps: 31.556050437870535
# Detection of Image 334
# Fps: 49.6337968167564
# Detection of Image 335
# Fps: 24.366929838320814
# Detection of Image 336
# Fps: 21.10086832281888
# Detection of Image 337
# Fps: 43.04852615157238
# Detection of Image 338
# Fps: 21.830438606992104
# Detection of Image 339
# Fps: 32.768
# Detection of Image 340
# Fps: 31.74088480573928
# Detection of Image 341
# Fps: 33.308482167673894
# Detection of Image 342
# Fps: 33.42261321348601
# Detection of Image 343
# Fps: 31.394961002410216
# Detection of Image 344
# Fps: 32.70488978299687
# Detection of Image 345
# Fps: 42.83005034259514
# Detection of Image 346
# Fps: 23.294829855653614
# Detection of Image 347
# Fps: 35.69468533253904
# Detection of Image 348
# Fps: 31.891725024141365
# Detection of Image 349
# Fps: 30.699838240998954
# Detection of Image 350
# Fps: 30.054845759736306
# Detection of Image 351
# Fps: 32.088869167387095
# Detection of Image 352
# Fps: 33.28469284915048
# Detection of Image 353
# Fps: 28.00272395882015
# Detection of Image 354
# Fps: 30.40937300620614
# Detection of Image 355
# Fps: 29.730811761036605
# Detection of Image 356
# Fps: 18.896921475781344
# Detection of Image 357
# Fps: 31.852005984158687
# Detection of Image 358
# Fps: 76.28087660270982
# Detection of Image 359
# Fps: 26.991589067718625
# Detection of Image 360
# Fps: 32.27380732533087
# Detection of Image 361
# Fps: 23.27505188506487
# Detection of Image 362
# Fps: 31.59003713104321
# Detection of Image 363
# Fps: 31.899244025979954
# Detection of Image 364
# Fps: 32.18984029040898
# Detection of Image 365
# Fps: 31.837016008440678
# Detection of Image 366
# Fps: 31.421067220028917
# Detection of Image 367
# Fps: 32.448333217289054
# Detection of Image 368
# Fps: 31.450518138600202
# Detection of Image 369
# Fps: 33.06611166296138
# Detection of Image 370
# Fps: 38.289110212428
# Detection of Image 371
# Fps: 15.386915832993994
# Detection of Image 372
# Fps: 22.2941185850586
# Detection of Image 373
# Fps: 58.50122740459719
# Detection of Image 374
# Fps: 16.745533450711253
# Detection of Image 375
# Fps: 32.208626740283975
# Detection of Image 376
# Fps: 63.12539883209921
# Detection of Image 377
# Fps: 125.33405050052293
# Detection of Image 378
# Fps: 26.248030288807534
# Detection of Image 379
# Fps: 30.10964745407427
# Detection of Image 380
# Fps: 31.29657210225492
# Detection of Image 381
# Fps: 31.557474983071252
# Detection of Image 382
# Fps: 29.609290176838094
# Detection of Image 383
# Fps: 16.26108903405897
# Detection of Image 384
# Fps: 40.538384961097954
# Detection of Image 385
# Fps: 26.58762376865246
# Detection of Image 386
# Fps: 32.87742016398326
# Detection of Image 387
# Fps: 31.694593267087317
# Detection of Image 388
# Fps: 31.668987179293577
# Detection of Image 389
# Fps: 32.02247671400214
# Detection of Image 390
# Fps: 31.200422521591
# Detection of Image 391
# Fps: 32.680681304639165
# Detection of Image 392
# Fps: 31.837016008440678
# Detection of Image 393
# Fps: 32.47571853320119
# Detection of Image 394
# Fps: 20.633847092333955
# Detection of Image 395
# Fps: 22.147672128377486
# Detection of Image 396
# Fps: 63.365723954556444
# Detection of Image 397
# Fps: 21.506604315366314
# Detection of Image 398
# Fps: 31.66755254892486
# Detection of Image 399
# Fps: 44.438718426852006
# Detection of Image 400
# Fps: 21.373229855127114
# Detection of Image 401
# Fps: 31.73151965864988
# Detection of Image 402
# Fps: 63.12539883209921
# Detection of Image 403
# Fps: 32.29443242452474
# Detection of Image 404
# Fps: 21.350817268779874
# Detection of Image 405
# Fps: 53.08640787758357
# Detection of Image 406
# Fps: 31.382041555370996
# Detection of Image 407
# Fps: 26.825518851331903
# Detection of Image 408
# Fps: 34.19511161114644
# Detection of Image 409
# Fps: 28.874459589701225
# Detection of Image 410
# Fps: 32.56143837530665
# Detection of Image 411
# Fps: 29.650944463296007
# Detection of Image 412
# Fps: 32.61435580818488
# Detection of Image 413
# Fps: 22.06494852411239
# Detection of Image 414
# Fps: 31.784662018793576
# Detection of Image 415
# Fps: 36.87916223369178
# Detection of Image 416
# Fps: 24.61258237341048
# Detection of Image 417
# Fps: 30.30128594133796
# Detection of Image 418
# Fps: 56.75340982896731
# Detection of Image 419
# Fps: 30.681872380269635
# Detection of Image 420
# Fps: 30.109431307518914
# Detection of Image 421
# Fps: 25.140130786336364
# Detection of Image 422
# Fps: 31.926439021419764
# Detection of Image 423
# Fps: 31.79984381752428
# Detection of Image 424
# Fps: 39.0753034777667
# Detection of Image 425
# Fps: 21.842261765272593
# Detection of Image 426
# Fps: 32.524573892275
# Detection of Image 427
# Fps: 32.32056221681102
# Detection of Image 428
# Fps: 31.98706577693041
# Detection of Image 429
# Fps: 32.70488978299687
# Detection of Image 430
# Fps: 48.01556901308484
# Detection of Image 431
# Fps: 13.280006079104345
# Detection of Image 432
# Fps: 19.70035461825697
# Detection of Image 433
# Fps: 34.37785026965887
# Detection of Image 434
# Fps: 63.1824536032779
# Detection of Image 435
# Fps: 81.53462151549317
# Detection of Image 436
# Fps: 32.06213212249079
# Detection of Image 437
# Fps: 31.77286397139589
# Detection of Image 438
# Fps: 31.751937984496124
# Detection of Image 439
# Fps: 24.24116885518772
# Detection of Image 440
# Fps: 39.05892870446249
# Detection of Image 441
# Fps: 35.01936194905277
# Detection of Image 442
# Fps: 30.58388082338615
# Detection of Image 443
# Fps: 16.42892283587936
# Detection of Image 444
# Fps: 30.919816293282025
# Detection of Image 445
# Fps: 31.35295304873035
# Detection of Image 446
# Fps: 39.740238575746375
# Detection of Image 447
# Fps: 27.758648303430203
# Detection of Image 448
# Fps: 30.30719761837665
# Detection of Image 449
# Fps: 31.482150899210374
# Detection of Image 450
# Fps: 28.10837761947205
# Detection of Image 451
# Fps: 38.52084787480254
# Detection of Image 452
# Fps: 19.6589876870726
# Detection of Image 453
# Fps: 46.98184262111453
# Detection of Image 454
# Fps: 65.25763539900113
# Detection of Image 455
# No Face Detected
# Fps: 17.55460408740672
# Detection of Image 456
# No Face Detected
# Fps: 30.42172449808518
# Detection of Image 457
# No Face Detected
# Fps: 30.9369209889656
# Detection of Image 458
# No Face Detected
# Fps: 31.36115805057499
# Detection of Image 459
# No Face Detected
# Fps: 31.791166728566772
# Detection of Image 460
# No Face Detected
# Fps: 32.30015247893788
# Detection of Image 461
# No Face Detected
# Fps: 25.02538155869262
# Detection of Image 462
# No Face Detected
# Fps: 37.663691384853
# Detection of Image 463
# No Face Detected
# Fps: 30.812603307302954
# Detection of Image 464
# No Face Detected
# Fps: 31.343112711946734
# Detection of Image 465
# No Face Detected
# Fps: 33.45647145158974
# Detection of Image 466
# No Face Detected
# Fps: 30.931217321406184
# Detection of Image 467
# No Face Detected
# Fps: 30.882707231949578
# Detection of Image 468
# No Face Detected
# Fps: 32.71458321958677
# Detection of Image 469
# No Face Detected
# Fps: 30.890895432249703
# Detection of Image 470
# No Face Detected
# Fps: 30.660789344795575
# Detection of Image 471
# No Face Detected
# Fps: 21.709872773010073
# Detection of Image 472
# Fps: 32.20714280229442
# Detection of Image 473
# Fps: 27.784759898514146
# Detection of Image 474
# Fps: 34.26187111477793
# Detection of Image 475
# No Face Detected
# Fps: 24.795185566157084
# Detection of Image 476
# Fps: 30.315740780895386
# Detection of Image 477
# Fps: 42.29237501764575
# Detection of Image 478
# Fps: 26.83822089697404
# Detection of Image 479
# Fps: 30.628324400110994
# Detection of Image 480
# Fps: 32.015143882146404
# Detection of Image 481
# No Face Detected
# Fps: 29.730601019301517
# Detection of Image 482
# No Face Detected
# Fps: 30.618933598084446
# Detection of Image 483
# No Face Detected
# Fps: 41.29308681355465
# Detection of Image 484
# No Face Detected
# Fps: 29.569003440302296
# Detection of Image 485
# No Face Detected
# Fps: 39.897115896811506
# Detection of Image 486
# No Face Detected
# Fps: 26.303668073524523
# Detection of Image 487
# No Face Detected
# Fps: 32.24899277256651
# Detection of Image 488
# No Face Detected
# Fps: 30.795635765576588
# Detection of Image 489
# No Face Detected
# Fps: 29.866514757717095
# Detection of Image 490
# Fps: 31.071910628430885
# Detection of Image 491
# Fps: 20.902854124201998
# Detection of Image 492
# No Face Detected
# Fps: 33.81930479515566
# Detection of Image 493
# Fps: 29.617026084254828
# Detection of Image 494
# Fps: 32.272565690762896
# Detection of Image 495
# Fps: 30.382058934314607
# Detection of Image 496
# Fps: 32.73117742539643
# Detection of Image 497
# Fps: 33.27465866990345
# Detection of Image 498
# Fps: 29.146339599041035
# Detection of Image 499
# Fps: 34.984602552339645
# Detection of Image 500
# No Face Detected
# Fps: 29.91913715867264
# Detection of Image 501
# Fps: 31.532089883248005
# Detection of Image 502
# Fps: 31.794058565353506
# Detection of Image 503
# Fps: 15.895221925782197
# Detection of Image 504
# Fps: 28.263504043126684
# Detection of Image 505
# Fps: 34.61275148954431
# Detection of Image 506
# Fps: 30.48518370461896
# Detection of Image 507
# Fps: 30.794957452588452
# Detection of Image 508
# Fps: 28.950792741428938
# Detection of Image 509
# Fps: 24.45358877338635
# Detection of Image 510
# Fps: 32.08739624373637
# Detection of Image 511
# Fps: 64.67900320750061
# Detection of Image 512
# Fps: 65.15221274678845
# Detection of Image 513
# Fps: 32.56143837530665
# Detection of Image 514
# Fps: 21.59063135407819
# Detection of Image 515
# Fps: 15.72136886689906
# Detection of Image 516
# Fps: 30.837522883841984
# Detection of Image 517
# Fps: 68.09045601389633
# Detection of Image 518
# Fps: 24.99749089630429
# Detection of Image 519
# Fps: 27.055312945486914
# Detection of Image 520
# Fps: 30.736058389881432
# Detection of Image 521
# Fps: 31.638887212600327
# Detection of Image 522
# Fps: 32.15282600863173
# Detection of Image 523
# No Face Detected
# Fps: 31.06822811344933
# Detection of Image 524
# No Face Detected
# Fps: 28.038665686208972
# Detection of Image 525
# Fps: 35.90737015127259
# Detection of Image 526
# No Face Detected
# Fps: 30.891350459580487
# Detection of Image 527
# No Face Detected
# Fps: 41.33989099044934
# Detection of Image 528
# No Face Detected
# Fps: 32.35272247633887
# Detection of Image 529
# No Face Detected
# Fps: 20.621774701069857
# Detection of Image 530
# No Face Detected
# Fps: 30.51157377096882
# Detection of Image 531
# No Face Detected
# Fps: 31.50958591261494
# Detection of Image 532
# No Face Detected
# Fps: 26.25378067100651
# Detection of Image 533
# No Face Detected
# Fps: 31.60312843774017
# Detection of Image 534
# Fps: 30.164215492380382
# Detection of Image 535
# No Face Detected
# Fps: 29.81216993268937
# Detection of Image 536
# Fps: 28.525694387768983
# Detection of Image 537
# Fps: 37.88618708675073
# Detection of Image 538
# No Face Detected
# Fps: 33.58425481827863
# Detection of Image 539
# Fps: 30.80083715806866
# Detection of Image 540
# No Face Detected
# Fps: 31.281167029623223
# Detection of Image 541
# No Face Detected
# Fps: 29.013274305675647
# Detection of Image 542
# No Face Detected
# Fps: 37.362408694102974
# Detection of Image 543
# Fps: 27.00583989543561
# Detection of Image 544
# No Face Detected
# Fps: 29.574215747798313
# Detection of Image 545
# No Face Detected
# Fps: 31.70034237516155
# Detection of Image 546
# Fps: 29.49726076529787
# Detection of Image 547
# Fps: 33.436734693877554
# Detection of Image 548
# Fps: 21.502194151663044
# Detection of Image 549
# Fps: 31.547268583634818
# Detection of Image 550
# Fps: 40.94640451412617
# Detection of Image 551
# Fps: 32.02321018194034
# Detection of Image 552
# Fps: 32.59914660780488
# Detection of Image 553
# Fps: 29.629788707022612
# Detection of Image 554
# Fps: 32.756739870669456
# Detection of Image 555
# Fps: 30.401438056304542
# Detection of Image 556
# No Face Detected
# Fps: 31.82421317794167
# Detection of Image 557
# No Face Detected
# Fps: 30.19983439536307
# Detection of Image 558
# Fps: 28.82544482396036
# Detection of Image 559
# Fps: 30.96981511016599
# Detection of Image 560
# No Face Detected
# Fps: 34.49518467649744
# Detection of Image 561
# Fps: 32.154058446536446
# Detection of Image 562
# Fps: 27.737354098469066
# Detection of Image 563
# Fps: 15.778737491535626
# Detection of Image 564
# No Face Detected
# Fps: 29.030142371661327
# Detection of Image 565
# No Face Detected
# Fps: 31.75121689036253
# Detection of Image 566
# No Face Detected
# Fps: 31.426246581500767
# Detection of Image 567
# Fps: 21.44217575788559
# Detection of Image 568
# Fps: 30.612005984746197
# Detection of Image 569
# Fps: 51.28576843598303
# Detection of Image 570
# No Face Detected
# Fps: 43.5808067164024
# Detection of Image 571
# No Face Detected
# Fps: 64.29037400367872
# Detection of Image 572
# No Face Detected
# Fps: 36.239331599547256
# Detection of Image 573
# No Face Detected
# Fps: 32.64710369413267
# Detection of Image 574
# No Face Detected
# Fps: 21.535314534513564
# Detection of Image 575
# No Face Detected
# Fps: 19.10627035645143
# Detection of Image 576
# No Face Detected
# Fps: 30.010976037321388
# Detection of Image 577
# Fps: 32.41097287690287
# Detection of Image 578
# Fps: 31.47270162379566
# Detection of Image 579
# Fps: 30.510464025139846
# Detection of Image 580
# Fps: 36.67311357873568
# Detection of Image 581
# Fps: 28.904705460760262
# Detection of Image 582
# Fps: 30.740338456351736
# Detection of Image 583
# Fps: 28.206482851378613
# Detection of Image 584
# Fps: 38.45233685986175
# Detection of Image 585
# Fps: 30.04881683299542
# Detection of Image 586
# Fps: 20.15872039372501
# Detection of Image 587
# Fps: 30.14925458962895
# Detection of Image 588
# Fps: 26.315220187342756
# Detection of Image 589
# Fps: 31.849345442395894
# Detection of Image 590
# No Face Detected
# Fps: 31.74857315873136
# Detection of Image 591
# No Face Detected
# Fps: 31.491842296920872
# Detection of Image 592
# Fps: 33.403714440444716
# Detection of Image 593
# No Face Detected
# Fps: 31.31175860189768
# Detection of Image 594
# No Face Detected
# Fps: 31.147363730877768
# Detection of Image 595
# No Face Detected
# Fps: 32.053066371174204
# Detection of Image 596
# No Face Detected
# Fps: 37.211916886988305
# Detection of Image 597
# No Face Detected
# Fps: 36.12478252631216
# Detection of Image 598
# No Face Detected
# Fps: 24.42937603019378
# Detection of Image 599
# Fps: 41.417043546953686
# Detection of Image 600
# No Face Detected
# Fps: 31.639364542944648
# Detection of Image 601
# No Face Detected
# Fps: 31.497281547565407
# Detection of Image 602
# No Face Detected
# Fps: 29.216586908518448
# Detection of Image 603
# No Face Detected
# Fps: 33.41995012071425
# Detection of Image 604
# No Face Detected
# Fps: 25.70669281686688
# Detection of Image 605
# Fps: 37.03677801619469
# Detection of Image 606
# No Face Detected
# Fps: 17.614170946703567
# Detection of Image 607
# No Face Detected
# Fps: 30.320562125900008
# Detection of Image 608
# No Face Detected
# Fps: 35.2441789138454
# Detection of Image 609
# Fps: 31.10463124327932
# Detection of Image 610
# No Face Detected
# Fps: 35.31391236991884
# Detection of Image 611
# Fps: 33.25091762392878
# Detection of Image 612
# No Face Detected
# Fps: 30.639511439675072
# Detection of Image 613
# Fps: 33.35801997836737
# Detection of Image 614
# Fps: 30.25844058405956
# Detection of Image 615
# Fps: 38.40550860261329
# Detection of Image 616
# Fps: 31.344752339102623
# Detection of Image 617
# Fps: 39.05492806927697
# Detection of Image 618
# Fps: 23.352545543628345
# Detection of Image 619
# Fps: 32.11761823082578
# Detection of Image 620
# Fps: 31.374529677974344
# Detection of Image 621
# Fps: 32.65523738341041
# Detection of Image 622
# No Face Detected
# Fps: 39.292008206319615
# Detection of Image 623
# Fps: 15.685622181168146
# Detection of Image 624
# Fps: 20.844472937446266
# Detection of Image 625
# No Face Detected
# Fps: 30.42062127838581
# Detection of Image 626
# No Face Detected
# Fps: 109.88770992166418
# Detection of Image 627
# Fps: 44.23484744618695
# Detection of Image 628
# No Face Detected
# Fps: 31.896333024076412
# Detection of Image 629
# Fps: 32.52684394605619
# Detection of Image 630
# Fps: 30.218763959134858
# Detection of Image 631
# Fps: 32.289708690028945
# Detection of Image 632
# Fps: 28.01544277756255
# Detection of Image 633
# Fps: 31.89148253471008
# Detection of Image 634
# Fps: 32.41397857772145
# Detection of Image 635
# Fps: 15.302317436226723
# Detection of Image 636
# Fps: 31.16680537391511
# Detection of Image 637
# Fps: 30.971187216634917
# Detection of Image 638
# Fps: 37.25223816967458
# Detection of Image 639
# Fps: 30.319027895242847
# Detection of Image 640
# Fps: 30.97896478373907
# Detection of Image 641
# Fps: 21.667143646779866
# Detection of Image 642
# Fps: 33.050478306778245
# Detection of Image 643
# Fps: 31.620282556579166
# Detection of Image 644
# Fps: 21.638639248016343
# Detection of Image 645
# Fps: 41.39783057137499
# Detection of Image 646
# Fps: 67.29945605956068
# Detection of Image 647
# Fps: 19.490079088484308
# Detection of Image 648
# Fps: 31.269040376930874
# Detection of Image 649
# Fps: 31.950759480171246
# Detection of Image 650
# No Face Detected
# Fps: 30.00453540693474
# Detection of Image 651
# Fps: 32.37544769667778
# Detection of Image 652
# Fps: 31.818177680339247
# Detection of Image 653
# No Face Detected
# Fps: 30.639959091241142
# Detection of Image 654
# Fps: 32.1925580252978
# Detection of Image 655
# Fps: 28.945797849581098
# Detection of Image 656
# Fps: 32.43277684557271
# Detection of Image 657
# Fps: 31.10647670891521
# Detection of Image 658
# Fps: 34.35729322815554
# Detection of Image 659
# Fps: 29.833799230380755
# Detection of Image 660
# Fps: 30.94536627834055
# Detection of Image 661
# Fps: 32.55992175006598
# Detection of Image 662
# Fps: 31.613609297978503
# Detection of Image 663
# Fps: 20.434302195285934
# Detection of Image 664
# Fps: 33.38111723929359
# Detection of Image 665
# Fps: 30.595928133229265
# Detection of Image 666
# Fps: 32.071693467605655
# Detection of Image 667
# Fps: 29.88077054599339
# Detection of Image 668
# Fps: 32.604214764891985
# Detection of Image 669
# Fps: 29.004045335417086
# Detection of Image 670
# Fps: 36.16870607510887
# Detection of Image 671
# Fps: 32.41823760830415
# Detection of Image 672
# Fps: 30.71670035445411
# Detection of Image 673
# Fps: 32.443815314165484
# Detection of Image 674
# Fps: 26.92712740346034
# Detection of Image 675
# Fps: 34.30165934721984
# Detection of Image 676
# Fps: 33.868733850129196
# Detection of Image 677
# Fps: 29.930452777678667
# Detection of Image 678
# Fps: 30.705232102724032
# Detection of Image 679
# Fps: 37.042992899282865
# Detection of Image 680
# Fps: 25.42927125015157
# Detection of Image 681
# Fps: 33.80594825501733
# Detection of Image 682
# Fps: 34.55543380650689
# Detection of Image 683
# Fps: 12.31622869995977
# Detection of Image 684
# Fps: 79.412007497586
# Detection of Image 685
# Fps: 56.9615123448407
# Detection of Image 686
# Fps: 32.15479795463083
# Detection of Image 687
# Fps: 30.86657099753468
# Detection of Image 688
# No Face Detected
# Fps: 31.046610953611108
# Detection of Image 689
# No Face Detected
# Fps: 32.88824765549039
# Detection of Image 690
# No Face Detected
# Fps: 31.69291683668072
# Detection of Image 691
# No Face Detected
# Fps: 30.109215164066818
# Detection of Image 692
# No Face Detected
# Fps: 11.370251894904632
# Detection of Image 693
# No Face Detected
# Fps: 79.37593913816923
# Detection of Image 694
# No Face Detected
# Fps: 63.97852283474175
# Detection of Image 695
# No Face Detected
# Fps: 21.922404285900953
# Detection of Image 696
# No Face Detected
# Fps: 31.3564689523183
# Detection of Image 697
# No Face Detected
# Fps: 40.92722624460881
# Detection of Image 698
# No Face Detected
# Fps: 32.146665235985715
# Detection of Image 699
# No Face Detected
# Fps: 31.432369846896336
# Detection of Image 700
# No Face Detected
# Fps: 26.423808683819267
# Detection of Image 701
# No Face Detected
# Fps: 21.82896161212424
# Detection of Image 702
# No Face Detected
# Fps: 31.71040833453039
# Detection of Image 703
# No Face Detected
# Fps: 64.26180882195223
# Detection of Image 704
# No Face Detected
# Fps: 62.9312367777461
# Detection of Image 705
# No Face Detected
# Fps: 21.710322266737062
# Detection of Image 706
# No Face Detected
# Fps: 62.27068115683829
# Detection of Image 707
# No Face Detected
# Fps: 13.373968885615257
# Detection of Image 708
# Fps: 32.66388387016385
# Detection of Image 709
# Fps: 32.624756926619064
# Detection of Image 710
# No Face Detected
# Fps: 43.280851107740254
# Detection of Image 711
# Fps: 25.699762260728903
# Detection of Image 712
# No Face Detected
# Fps: 32.43077065823353
# Detection of Image 713
# Fps: 32.86814512969203
# Detection of Image 714
# Fps: 31.522373701693997
# Detection of Image 715
# No Face Detected
# Fps: 32.42926618059797
# Detection of Image 716
# No Face Detected
# Fps: 21.770949256706253
# Detection of Image 717
# No Face Detected
# Fps: 32.79387641811117
# Detection of Image 718
# Fps: 32.032503684921984
# Detection of Image 719
# Fps: 32.679408166922485
# Detection of Image 720
# Fps: 32.261643424685985
# Detection of Image 721
# Fps: 21.333767369941608
# Detection of Image 722
# No Face Detected
# Fps: 47.83322309148553
# Detection of Image 723
# Fps: 31.005758639807798
# Detection of Image 724
# Fps: 24.517483662040988
# Detection of Image 725
# Fps: 32.23461780845079
# Detection of Image 726
# Fps: 33.082542612179864
# Detection of Image 727
# Fps: 31.41447777403288
# Detection of Image 728
# Fps: 32.82518763157689
# Detection of Image 729
# Fps: 31.829526310197764
# Detection of Image 730
# Fps: 31.88154364201613
# Detection of Image 731
# Fps: 27.299379722860433
# Detection of Image 732
# Fps: 28.504757244603926
# Detection of Image 733
# Fps: 31.654646722313625
# Detection of Image 734
# Fps: 30.064324676907198
# Detection of Image 735
# Fps: 30.89044041832376
# Detection of Image 736
# Fps: 32.01196736450852
# Detection of Image 737
# Fps: 33.06845794208314
# Detection of Image 738
# Fps: 36.8986284980338
# Detection of Image 739
# Fps: 31.85878027845928
# Detection of Image 740
# Fps: 20.96208706082263
# Detection of Image 741
# Fps: 30.047309979224874
# Detection of Image 742
# Fps: 31.687888609354577
# Detection of Image 743
# Fps: 25.646960988137458
# Detection of Image 744
# Fps: 43.19616061957384
# Detection of Image 745
# Fps: 30.821660310251833
# Detection of Image 746
# Fps: 32.09402546523017
# Detection of Image 747
# Fps: 28.72437148590252
# Detection of Image 748
# Fps: 27.03978957683282
# Detection of Image 749
# Fps: 30.827776797789145
# Detection of Image 750
# Fps: 40.46759160990294
# Detection of Image 751
# Fps: 31.762758328221672
# Detection of Image 752
# Fps: 34.62389486457705
# Detection of Image 753
# Fps: 23.637738741328103
# Detection of Image 754
# No Face Detected
# Fps: 9.842433913339356
# Detection of Image 755
# Fps: 113.08449716904826
# Detection of Image 756
# Fps: 65.97410931970114
# Detection of Image 757
# Fps: 32.979532784500584
# Detection of Image 758
# Fps: 32.59433331779115
# Detection of Image 759
# Fps: 25.638338580029952
# Detection of Image 760
# Fps: 25.919084431755685
# Detection of Image 761
# Fps: 65.84981552712144
# Detection of Image 762
# Fps: 63.68128264302199
# Detection of Image 763
# Fps: 32.504913357512635
# Detection of Image 764
# Fps: 30.634364386663258
# Detection of Image 765
# Fps: 30.987204113596736
# Detection of Image 766
# Fps: 29.663316760610197
# Detection of Image 767
# Fps: 14.05871114358689
# Detection of Image 768
# Fps: 34.19316023315534
# Detection of Image 769
# Fps: 36.618363730018075
# Detection of Image 770
# Fps: 33.17097552295464
# Detection of Image 771
# Fps: 32.437040817904816
# Detection of Image 772
# Fps: 31.139039021203303
# Detection of Image 773
# Fps: 30.85680654464128
# Detection of Image 774
# Fps: 30.506025848964658
# Detection of Image 775
# Fps: 32.348480641678236
# Detection of Image 776
# Fps: 33.812216337356006
# Detection of Image 777
# Fps: 26.3767820645851
# Detection of Image 778
# Fps: 34.17143136472141
# Detection of Image 779
# Fps: 21.900655301151346
# Detection of Image 780
# Fps: 25.117397657316694
# Detection of Image 781
# Fps: 27.49732192611532
# Detection of Image 782
# Fps: 48.833438118523695
# Detection of Image 783
# Fps: 31.839916192847546
# Detection of Image 784
# Fps: 31.07306159339764
# Detection of Image 785
# Fps: 31.2029757476566
# Detection of Image 786
# Fps: 30.70882906364628
# Detection of Image 787
# Fps: 32.091078806426935
# Detection of Image 788
# Fps: 12.420685427629728
# Detection of Image 789
# Fps: 38.415357702206386
# Detection of Image 790
# Fps: 65.12085455222953
# Detection of Image 791
# Fps: 65.13197819774213
# Detection of Image 792
# Fps: 32.05453614471643
# Detection of Image 793
# Fps: 51.35798599206544
# Detection of Image 794
# Fps: 22.80281399167111
# Detection of Image 795
# Fps: 49.579233551620604
# Detection of Image 796
# Fps: 33.299226726369106
# Detection of Image 797
# Fps: 23.831408133000757
# Detection of Image 798
# Fps: 21.28612898641928
# Detection of Image 799
# Fps: 31.20460074546361
# Detection of Image 800
# Fps: 32.48804442964145
# Detection of Image 801
# Fps: 32.2007139841081
# Detection of Image 802
# Fps: 30.95427306273063
# Detection of Image 803
# Fps: 25.389403083553773
# Detection of Image 804
# Fps: 47.47104295172882
# Detection of Image 805
# Fps: 30.652274637336937
# Detection of Image 806
# Fps: 34.24285026166042
# Detection of Image 807
# Fps: 32.146665235985715
# Detection of Image 808
# Fps: 32.3407483942602
# Detection of Image 809
# Fps: 32.713562587257144
# Detection of Image 810
# Fps: 31.09909615997746
# Detection of Image 811
# Fps: 31.8771821822963
# Detection of Image 812
# Fps: 32.43227527546878
# Detection of Image 813
# Fps: 30.26433555332674
# Detection of Image 814
# Fps: 20.979072466087793
# Detection of Image 815
# Fps: 16.11520344257886
# Detection of Image 816
# Fps: 32.48125145202509
# Detection of Image 817
# Fps: 20.792496604237513
# Detection of Image 818
# Fps: 63.88399969537735
# Detection of Image 819
# Fps: 66.35402066096091
# Detection of Image 820
# Fps: 47.23474892169781
# Detection of Image 821
# Fps: 32.21208979410025
# Detection of Image 822
# Fps: 24.256309421915844
# Detection of Image 823
# Fps: 33.24353842861559
# Detection of Image 824
# No Face Detected
# Fps: 32.543248192172804
# Detection of Image 825
# Fps: 31.92328008098214
# Detection of Image 826
# Fps: 30.157492090882943
# Detection of Image 827
# Fps: 16.17162113185432
# Detection of Image 828
# Fps: 31.913078544309094
# Detection of Image 829
# Fps: 32.16737479868088
# Detection of Image 830
# Fps: 31.819867388896476
# Detection of Image 831
# Fps: 21.83884992476192
# Detection of Image 832
# Fps: 61.69273537588068
# Detection of Image 833
# Fps: 22.167454151471908
# Detection of Image 834
# Fps: 32.3076164653685
# Detection of Image 835
# Fps: 32.159235717626494
# Detection of Image 836
# No Face Detected
# Fps: 21.329970148342902
# Detection of Image 837
# Fps: 33.054124767518836
# Detection of Image 838
# Fps: 66.31415516450853
# Detection of Image 839
# Fps: 19.81482933742766
# Detection of Image 840
# Fps: 32.91663919888245
# Detection of Image 841
# Fps: 31.427659430986296
# Detection of Image 842
# Fps: 32.44306245262295
# Detection of Image 843
# Fps: 28.879429889489447
# Detection of Image 844
# Fps: 30.112241454816964
# Detection of Image 845
# Fps: 30.63235079314072
# Detection of Image 846
# Fps: 36.33225054788944
# Detection of Image 847
# Fps: 25.74614204161807
# Detection of Image 848
# Fps: 32.03543959611081
# Detection of Image 849
# Fps: 32.058701235171824
# Detection of Image 850
# Fps: 37.988787145975415
# Detection of Image 851
# Fps: 31.8256620380909
# Detection of Image 852
# Fps: 26.363021533897346
# Detection of Image 853
# Fps: 30.840924131237223
# Detection of Image 854
# Fps: 36.39656713439027
# Detection of Image 855
# Fps: 34.927211105282005
# Detection of Image 856
# Fps: 21.040532948069668
# Detection of Image 857
# Fps: 29.906337345274085
# Detection of Image 858
# Fps: 26.753823975914372
# Detection of Image 859
# Fps: 32.283992333684836
# Detection of Image 860
# Fps: 29.27490874065595
# Detection of Image 861
# Fps: 31.903126188484066
# Detection of Image 862
# Fps: 31.03168050191622
# Detection of Image 863
# Fps: 30.968671780975658
# Detection of Image 864
# Fps: 30.892715622007806
# Detection of Image 865
# Fps: 32.68602956647782
# Detection of Image 866
# Fps: 36.48109104825523
# Detection of Image 867
# Fps: 34.146393884379606
# Detection of Image 868
# Fps: 29.332848450940624
# Detection of Image 869
# Fps: 33.410898778846075
# Detection of Image 870
# Fps: 30.488729292209726
# Detection of Image 871
# Fps: 30.738536177822077
# Detection of Image 872
# Fps: 30.19874721002232
# Detection of Image 873
# Fps: 26.027005559968227
# Detection of Image 874
# Fps: 29.120639857809376
# Detection of Image 875
# Fps: 12.949699282476875
# Detection of Image 876
# Fps: 60.12908035266289
# Detection of Image 877
# Fps: 74.5163892195356
# Detection of Image 878
# No Face Detected
# Fps: 38.70033862648668
# Detection of Image 879
# Fps: 28.909686179635106
# Detection of Image 880
# Fps: 39.7127707923042
# Detection of Image 881
# Fps: 30.975990546877885
# Detection of Image 882
# Fps: 32.83161124679066
# Detection of Image 883
# Fps: 33.92187373631173
# Detection of Image 884
# Fps: 28.42593797440902
# Detection of Image 885
# Fps: 20.9933530872107
# Detection of Image 886
# Fps: 56.61704597608056
# Detection of Image 887
# Fps: 15.75449706831337
# Detection of Image 888
# Fps: 30.566718652071884
# Detection of Image 889
# Fps: 33.03433936109886
# Detection of Image 890
# Fps: 30.042790324544626
# Detection of Image 891
# Fps: 32.79156894017575
# Detection of Image 892
# Fps: 32.14444793574642
# Detection of Image 893
# Fps: 32.66261204083699
# Detection of Image 894
# Fps: 21.057857214579776
# Detection of Image 895
# Fps: 31.75674611587268
# Detection of Image 896
# Fps: 74.74745602623278
# Detection of Image 897
# Fps: 56.39476161024014
# Detection of Image 898
# Fps: 29.009662270114745
# Detection of Image 899
# Fps: 16.954012441742492
# Detection of Image 900
# Fps: 29.965521429438954
# Detection of Image 901
# Fps: 31.054656380032874
# Detection of Image 902
# Fps: 30.424151863108495
# Detection of Image 903
# Fps: 31.462549977121167
# Detection of Image 904
# Fps: 29.36406278441311
# Detection of Image 905
# Fps: 34.149730095016324
# Detection of Image 906
# Fps: 32.260402725860295
# Detection of Image 907
# Fps: 30.422165808370202
# Detection of Image 908
# Fps: 28.38726794041407
# Detection of Image 909
# Fps: 31.373590946151143
# Detection of Image 910
# Fps: 32.34174589588779
# Detection of Image 911
# Fps: 30.772589875275127
# Detection of Image 912
# Fps: 31.669226296992623
# Detection of Image 913
# Fps: 21.60675870595508
# Detection of Image 914
# Fps: 31.934946969293204
# Detection of Image 915
# Fps: 30.527785258346494
# Detection of Image 916
# Fps: 30.85022470339887
# Detection of Image 917
# Fps: 33.01119969777344
# Detection of Image 918
# Fps: 32.26660717445322
# Detection of Image 919
# Fps: 31.790202899868877
# Detection of Image 920
# Fps: 30.902730501156743
# Detection of Image 921
# Fps: 32.77312080012502
# Detection of Image 922
# Fps: 32.52482610482564
# Detection of Image 923
# Fps: 28.958988096881992
# Detection of Image 924
# Fps: 29.941135739015596
# Detection of Image 925
# Fps: 37.99532566355648
# Detection of Image 926
# Fps: 24.965649422926973
# Detection of Image 927
# Fps: 31.471993156800803
# Detection of Image 928
# Fps: 30.948791357988252
# Detection of Image 929
# Fps: 33.150788005248096
# Detection of Image 930
# Fps: 37.02533500467859
# Detection of Image 931
# Fps: 29.2818575946495
# Detection of Image 932
# Fps: 33.03511991493719
# Detection of Image 933
# Fps: 18.87209391268352
# Detection of Image 934
# Fps: 37.245291396197594
# Detection of Image 935
# Fps: 27.93353446151592
# Detection of Image 936
# Fps: 35.31807541386686
# Detection of Image 937
# Fps: 28.121381159906136
# Detection of Image 938
# Fps: 31.51503129484781
# Detection of Image 939
# Fps: 50.12433375558689
# Detection of Image 940
# Fps: 24.974271338831166
# Detection of Image 941
# Fps: 32.01636578756536
# Detection of Image 942
# Fps: 32.72377177720737
# Detection of Image 943
# Fps: 32.190828504547376
# Detection of Image 944
# Fps: 32.245769683177905
# Detection of Image 945
# No Face Detected
# Fps: 32.76364857792324
# Detection of Image 946
# Fps: 32.827756776006325
# Detection of Image 947
# Fps: 15.879815846862128
# Detection of Image 948
# Fps: 32.142969905509275
# Detection of Image 949
# Fps: 32.77184045005274
# Detection of Image 950
# Fps: 31.845476356789263
# Detection of Image 951
# Fps: 19.908977852036795
# Detection of Image 952
# Fps: 32.441305911562466
# Detection of Image 953
# Fps: 69.88759476797468
# Detection of Image 954
# Fps: 59.211474391552315
# Detection of Image 955
# Fps: 30.558033470059815
# Detection of Image 956
# Fps: 31.87161094224924
# Detection of Image 957
# Fps: 32.14198462752791
# Detection of Image 958
# Fps: 31.710648078144374
# Detection of Image 959
# Fps: 15.673664621340647
# Detection of Image 960
# Fps: 30.085889922602952
# Detection of Image 961
# Fps: 31.389322117615365
# Detection of Image 962
# Fps: 32.71177663391047
# Detection of Image 963
# Fps: 32.19453484801965
# Detection of Image 964
# Fps: 31.205529391633
# Detection of Image 965
# Fps: 31.06109572403987
# Detection of Image 966
# Fps: 33.17543582117885
# Detection of Image 967
# Fps: 31.808284418558795
# Detection of Image 968
# Fps: 31.80129045954614
# Detection of Image 969
# Fps: 31.141350994164203
# Detection of Image 970
# Fps: 34.70181273631347
# Detection of Image 971
# Fps: 19.33937356774976
# Detection of Image 972
# Fps: 32.22793038533943
# Detection of Image 973
# Fps: 31.979992985345472
# Detection of Image 974
# Fps: 32.5697823402884
# Detection of Image 975
# Fps: 30.60619814508067
# Detection of Image 976
# Fps: 27.248302788948152
# Detection of Image 977
# Fps: 36.514756324761024
# Detection of Image 978
# Fps: 31.228763522921025
# Detection of Image 979
# Fps: 30.6982653882749
# Detection of Image 980
# Fps: 29.52342204734386
# Detection of Image 981
# Fps: 33.48398170249794
# Detection of Image 982
# Fps: 31.44391633555739
# Detection of Image 983
# Fps: 30.62720614544313
# Detection of Image 984
# Fps: 31.590750922648187
# Detection of Image 985
# Fps: 29.35871878149849
# Detection of Image 986
# Fps: 36.984850889723646
# Detection of Image 987
# Fps: 30.41554749818709
# Detection of Image 988
# Fps: 30.282471517479387
# Detection of Image 989
# Fps: 34.149730095016324
# Detection of Image 990
# Fps: 18.58691211075118
# Detection of Image 991
# Fps: 30.043220709266595
# Detection of Image 992
# Fps: 33.1604854330553
# Detection of Image 993
# Fps: 30.320562125900008
# Detection of Image 994
# Fps: 30.247966307044365
# Detection of Image 995
# ...
# Fps: 30.42680033950192
# Detection of Image 1940
# No Face Detected
# Fps: 22.735819601040763
# Detection of Image 1941
# Fps: 65.47155144154972
# Detection of Image 1942
# Fps: 20.49050538606219
# Detection of Image 1943
# Fps: 31.103016640465103
# Detection of Image 1944
# Fps: 33.76132137740071
# Detection of Image 1945
# Fps: 35.468901423219705
# Detection of Image 1946
# Fps: 24.356458871693622
# Detection of Image 1947
# Fps: 31.17560837830204
# Detection of Image 1948
# Fps: 32.25469674015857
# Detection of Image 1949
# Fps: 32.55309868446583
# Detection of Image 1950
# Fps: 46.75142395363094
# Detection of Image 1951
# Fps: 29.536104108277115
# Detection of Image 1952
# Fps: 21.333007817466978
# Detection of Image 1953
# Fps: 33.286277746474404
# Detection of Image 1954
# Fps: 25.0671097219151
# Detection of Image 1955
# Fps: 31.29914108964457
# Detection of Image 1956
# Fps: 31.335151248010877
# Detection of Image 1957
# Fps: 31.33327855013783
# Detection of Image 1958
# Fps: 31.394726008428208
# Detection of Image 1959
# Fps: 31.332810410643717
# Detection of Image 1960
# No Face Detected
# Fps: 31.316200516672392
# Detection of Image 1961
# No Face Detected
# Fps: 31.329065798220782
# Detection of Image 1962
# No Face Detected
# Fps: 45.61108332064638
# Detection of Image 1963
# No Face Detected
# Fps: 32.3357618089445
# Detection of Image 1964
# No Face Detected
# Fps: 32.36745277194716
# Detection of Image 1965
# No Face Detected
# Fps: 33.42181424109135
# Detection of Image 1966
# No Face Detected
# Fps: 17.28868444048738
# Detection of Image 1967
# No Face Detected
# Fps: 20.874246013576734
# Detection of Image 1968
# Fps: 16.587324311284416
# Detection of Image 1969
# Fps: 63.899571900851626
# Detection of Image 1970
# Fps: 21.12733408890568
# Detection of Image 1971
# Fps: 32.01001289771123
# Detection of Image 1972
# Fps: 32.041802583631906
# Detection of Image 1973
# Fps: 31.525453793829154
# Detection of Image 1974
# Fps: 31.99731467848615
# Detection of Image 1975
# Fps: 32.00268577227398
# Detection of Image 1976
# Fps: 63.660985049707826
# Detection of Image 1977
# No Face Detected
# Fps: 61.97074554534441
# Detection of Image 1978
# No Face Detected
# Fps: 63.66291759634504
# Detection of Image 1979
# No Face Detected
# Fps: 16.004945375730262
# Detection of Image 1980
# No Face Detected
# Fps: 31.539203080000302
# Detection of Image 1981
# No Face Detected
# Fps: 31.922551183499504
# Detection of Image 1982
# No Face Detected
# Fps: 32.05184166284579
# Detection of Image 1983
# No Face Detected
# Fps: 31.444623539025542
# Detection of Image 1984
# No Face Detected
# Fps: 31.992189406883085
# Detection of Image 1985
# No Face Detected
# Fps: 31.933001895741814
# Detection of Image 1986
# No Face Detected
# Fps: 31.53161578421128
# Detection of Image 1987
# No Face Detected
# Fps: 31.97779861698802
# Detection of Image 1988
# No Face Detected
# Fps: 15.999877930618815
# Detection of Image 1989
# No Face Detected
# Fps: 31.42436297977868
# Detection of Image 1990
# No Face Detected
# Fps: 21.34462402800961
# Detection of Image 1991
# No Face Detected
# Fps: 40.56426077621641
# Detection of Image 1992
# No Face Detected
# Fps: 26.114511991632007
# Detection of Image 1993
# No Face Detected
# Fps: 64.11054216407074
# Detection of Image 1994
# No Face Detected
# Fps: 31.929112459368316
# Detection of Image 1995
# No Face Detected
# Fps: 31.48995082397988
# Detection of Image 1996
# No Face Detected
# Fps: 31.932029447815395
# Detection of Image 1997
# No Face Detected
# Fps: 32.00854720422476
# Detection of Image 1998
# No Face Detected
# Fps: 31.463022001515277
# Detection of Image 1999
# No Face Detected
# Fps: 31.937621832358673
# Detection of Image 2000
# No Face Detected
# Fps: 32.03568427966943
# Detection of Image 2001
# No Face Detected
# Fps: 31.529719530621602
# Detection of Image 2002
# No Face Detected
# Fps: 31.92400901175181
# Detection of Image 2003
# No Face Detected
# Fps: 32.00219741650962
# Detection of Image 2004
# No Face Detected
# Fps: 30.529562907158713
# Detection of Image 2005
# No Face Detected
# Fps: 33.01379804324384
# Detection of Image 2006
# No Face Detected
# Fps: 32.00292995574546
# Detection of Image 2007
# No Face Detected
# Fps: 25.803638332297737
# Detection of Image 2008
# No Face Detected
# Fps: 25.088101062907114
# Detection of Image 2009
# No Face Detected
# Fps: 32.03299296608292
# Detection of Image 2010
# No Face Detected
# Fps: 21.018601667735727
# Detection of Image 2011
# No Face Detected
# Fps: 32.00659315502308
# Detection of Image 2012
# No Face Detected
# Fps: 64.0214915895839
# Detection of Image 2013
# No Face Detected
# Fps: 15.860720147024345
# Detection of Image 2014
# No Face Detected
# Fps: 32.013922069991985
# Detection of Image 2015
# No Face Detected
# Fps: 32.01880987823963
# Detection of Image 2016
# No Face Detected
# Fps: 31.45570721463927
# Detection of Image 2017
# No Face Detected
# Fps: 32.00708164495624
# Detection of Image 2018
# No Face Detected
# Fps: 63.68128264302199
# Detection of Image 2019
# No Face Detected
# Fps: 33.734438966324305
# Detection of Image 2020
# No Face Detected
# Fps: 24.451450424400708
# Detection of Image 2021
# No Face Detected
# Fps: 31.980480663657435
# Detection of Image 2022
# No Face Detected
# Fps: 31.956601904761904
# Detection of Image 2023
# No Face Detected
# Fps: 62.15072755830839
# Detection of Image 2024
# Fps: 21.30061449393124
# Detection of Image 2025
# Fps: 32.0092800341896
# Detection of Image 2026
# No Face Detected
# Fps: 21.09248540379074
# Detection of Image 2027
# Fps: 16.00983269906826
# Detection of Image 2028
# No Face Detected
# Fps: 21.144588456516587
# Detection of Image 2029
# Fps: 31.945162494192555
# Detection of Image 2030
# Fps: 63.96096132731487
# Detection of Image 2031
# No Face Detected
# Fps: 31.404128512492605
# Detection of Image 2032
# Fps: 64.35449175297276
# Detection of Image 2033
# No Face Detected
# Fps: 32.00683739812582
# Detection of Image 2034
# No Face Detected
# Fps: 31.495625924563157
# Detection of Image 2035
# No Face Detected
# Fps: 31.924980971228496
# Detection of Image 2036
# No Face Detected
# Fps: 32.02076541946911
# Detection of Image 2037
# No Face Detected
# Fps: 31.989993364502375
# Detection of Image 2038
# No Face Detected
# Fps: 31.564599638771824
# Detection of Image 2039
# No Face Detected
# Fps: 15.984329328013231
# Detection of Image 2040
# No Face Detected
# Fps: 31.437788571085928
# Detection of Image 2041
# No Face Detected
# Fps: 32.01270035109144
# Detection of Image 2042
# No Face Detected
# Fps: 31.996826486630813
# Detection of Image 2043
# No Face Detected
# Fps: 31.960254505276794
# Detection of Image 2044
# No Face Detected
# Fps: 32.10188586823414
# Detection of Image 2045
# No Face Detected
# Fps: 31.969755175462666
# Detection of Image 2046
# No Face Detected
# Fps: 31.490187245671727
# Detection of Image 2047
# No Face Detected
# Fps: 31.90725202163511
# Detection of Image 2048
# No Face Detected
# Fps: 21.344189549534878
# Detection of Image 2049
# No Face Detected
# Fps: 31.582900988682486
# Detection of Image 2050
# No Face Detected
# Fps: 32.00732589551441
# Detection of Image 2051
# No Face Detected
# Fps: 21.32183779497138
# Detection of Image 2052
# No Face Detected
# Fps: 31.499173901288714
# Detection of Image 2053
# Fps: 32.036907753530755
# Detection of Image 2054
# No Face Detected
# Fps: 32.012944687411746
# Detection of Image 2055
# No Face Detected
# Fps: 31.50816568758545
# Detection of Image 2056
# No Face Detected
# Fps: 32.005616219887216
# Detection of Image 2057
# No Face Detected
# Fps: 32.0422921489087
# Detection of Image 2058
# No Face Detected
# Fps: 31.54489594849695
# Detection of Image 2059
# No Face Detected
# Fps: 32.00634891564794
# Detection of Image 2060
# Fps: 31.962446466401474
# Detection of Image 2061
# Fps: 31.587420171104952
# Detection of Image 2062
# No Face Detected
# Fps: 32.001464910808295
# Detection of Image 2063
# No Face Detected
# Fps: 31.97828622837581
# Detection of Image 2064
# No Face Detected
# Fps: 64.03908635641871
# Detection of Image 2065
# No Face Detected
# Fps: 21.117016241906736
# Detection of Image 2066
# No Face Detected
# Fps: 32.00659315502308
# Detection of Image 2067
# Fps: 30.07553474497881
# Detection of Image 2068
# Fps: 22.06378781582228
# Detection of Image 2069
# Fps: 32.00659315502308
# Detection of Image 2070
# Fps: 31.605271684663435
# Detection of Image 2071
# Fps: 31.920121765601216
# Detection of Image 2072
# Fps: 32.09083327595045
# Detection of Image 2073
# Fps: 31.614562448179694
# Detection of Image 2074
# Fps: 63.9873072052968
# Detection of Image 2075
# Fps: 15.994203760691583
# Detection of Image 2076
# Fps: 34.73112242785575
# Detection of Image 2077
# Fps: 74.45950647967335
# Detection of Image 2078
# Fps: 28.06568258769054
# Detection of Image 2079
# Fps: 21.11403976843695
# Detection of Image 2080
# Fps: 63.999023452400934
# Detection of Image 2081
# Fps: 32.00830293502648
# Detection of Image 2082
# Fps: 21.384017701461186
# Detection of Image 2083
# Fps: 31.948812480004875
# Detection of Image 2084
# Fps: 64.19296285526255
# Detection of Image 2085
# Fps: 32.012944687411746
# Detection of Image 2086
# Fps: 31.59574836721934
# Detection of Image 2087
# No Face Detected
# Fps: 21.333550349429824
# Detection of Image 2088
# No Face Detected
# Fps: 31.94929920780012
# Detection of Image 2089
# No Face Detected
# Fps: 21.126376338561656
# Detection of Image 2090
# Fps: 32.06752500076455
# Detection of Image 2091
# Fps: 31.985358264954396
# Detection of Image 2092
# Fps: 31.542049257379208
# Detection of Image 2093
# Fps: 32.072674440833495
# Detection of Image 2094
# Fps: 31.996826486630813
# Detection of Image 2095
# Fps: 31.533749342154724
# Detection of Image 2096
# Fps: 31.94710904950148
# Detection of Image 2097
# Fps: 64.2559019532746
# Detection of Image 2098
# Fps: 31.592654524638075
# Detection of Image 2099
# Fps: 12.7882919690225
# Detection of Image 2100
# Fps: 31.56768798874062
# Detection of Image 2101
# Fps: 21.324331057343752
# Detection of Image 2102
# Fps: 64.1066226481422
# Detection of Image 2103
# Fps: 31.60360468971337
# Detection of Image 2104
# Fps: 31.915264038959062
# Detection of Image 2105
# Fps: 16.02598206473355
# Detection of Image 2106
# Fps: 31.565549835937265
# Detection of Image 2107
# Fps: 31.97341078357384
# Detection of Image 2108
# Fps: 32.0788068833652
# Detection of Image 2109
# Fps: 31.500829897333062
# Detection of Image 2110
# Fps: 63.9873072052968
# Detection of Image 2111
# Fps: 31.94078361192552
# Detection of Image 2112
# Fps: 31.53944024182997
# Detection of Image 2113
# Fps: 31.993897648306216
# Detection of Image 2114
# Fps: 31.9449191914576
# Detection of Image 2115
# No Face Detected
# Fps: 27.963890926061737
# Detection of Image 2116
# Fps: 36.73671302946432
# Detection of Image 2117
# Fps: 32.0134333712419
# Detection of Image 2118
# Fps: 23.923978142575205
# Detection of Image 2119
# Fps: 47.283738233470494
# Detection of Image 2120
# Fps: 32.0053719954216
# Detection of Image 2121
# Fps: 31.969024154147515
# Detection of Image 2122
# Fps: 31.45877429177886
# Detection of Image 2123
# Fps: 31.9189071953122
# Detection of Image 2124
# Fps: 18.569055588021747
# Detection of Image 2125
# Fps: 40.51528148062285
# Detection of Image 2126
# Fps: 16.013255601751634
# Detection of Image 2127
# Fps: 31.55438863101194
# Detection of Image 2128
# Fps: 32.00781440781441
# Detection of Image 2129
# Fps: 32.00634891564794
# Detection of Image 2130
# Fps: 31.520004809571045
# Detection of Image 2131
# Fps: 63.6880513840594
# Detection of Image 2132
# Fps: 32.021009878918356
# Detection of Image 2133
# Fps: 24.54043554068128
# Detection of Image 2134
# Fps: 45.017269321999336
# Detection of Image 2135
# Fps: 21.354187031606386
# Detection of Image 2136
# No Face Detected
# Fps: 63.71998055420515
# Detection of Image 2137
# No Face Detected
# Fps: 31.97097361861713
# Detection of Image 2138
# No Face Detected
# Fps: 32.016121399019895
# Detection of Image 2139
# No Face Detected
# Fps: 32.000488288700694
# Detection of Image 2140
# No Face Detected
# Fps: 21.10522157870107
# Detection of Image 2141
# No Face Detected
# Fps: 64.00585991149092
# Detection of Image 2142
# No Face Detected
# Fps: 32.021009878918356
# Detection of Image 2143
# Fps: 21.124035536574066
# Detection of Image 2144
# Fps: 21.317611421426864
# Detection of Image 2145
# Fps: 32.053801241096814
# Detection of Image 2146
# Fps: 61.838264997714774
# Detection of Image 2147
# Fps: 31.9261960038059
# Detection of Image 2148
# Fps: 32.01245601850085
# Detection of Image 2149
# Fps: 31.497045019336912
# Detection of Image 2150
# Fps: 31.999511726200467
# Detection of Image 2151
# Fps: 21.33789159875055
# Detection of Image 2152
# Fps: 21.14778680300303
# Detection of Image 2153
# No Face Detected
# Fps: 32.002441592528726
# Detection of Image 2154
# No Face Detected
# Fps: 32.01489951225469
# Detection of Image 2155
# Fps: 31.51124300364374
# Detection of Image 2156
# No Face Detected
# Fps: 63.74031579107336
# Detection of Image 2157
# No Face Detected
# Fps: 32.04645405785364
# Detection of Image 2158
# No Face Detected
# Fps: 31.58171194506355
# Detection of Image 2159
# Fps: 16.001770215363486
# Detection of Image 2160
# Fps: 30.011834996958964
# Detection of Image 2161
# No Face Detected
# Fps: 33.66431231539746
# Detection of Image 2162
# Fps: 32.00415092899927
# Detection of Image 2163
# Fps: 15.901248047556223
# Detection of Image 2164
# Fps: 31.976579653574042
# Detection of Image 2165
# Fps: 64.1487825767772
# Detection of Image 2166
# Fps: 64.02833284992444
# Detection of Image 2167
# Fps: 62.46357300291893
# Detection of Image 2168
# Fps: 21.33485253873465
# Detection of Image 2169
# Fps: 31.976335872042938
# Detection of Image 2170
# Fps: 50.854226026649854
# Detection of Image 2171
# Fps: 16.943328391550764
# Detection of Image 2172
# Fps: 31.98072450839109
# Detection of Image 2173
# Fps: 31.437788571085928
# Detection of Image 2174
# Fps: 32.03201441870766
# Detection of Image 2175
# Fps: 32.037152459517266
# Detection of Image 2176
# Fps: 32.00879147715132
# Detection of Image 2177
# No Face Detected
# Fps: 21.301263559907365
# Detection of Image 2178
# Fps: 26.496756056729524
# Detection of Image 2179
# Fps: 39.66394946380951
# Detection of Image 2180
# Fps: 32.084941671447694
# Detection of Image 2181
# Fps: 32.00512777468314
# Detection of Image 2182
# Fps: 15.898897316639564
# Detection of Image 2183
# Fps: 32.001220749692905
# Detection of Image 2184
# Fps: 31.44273773379812
# Detection of Image 2185
# Fps: 31.911378922060926
# Detection of Image 2186
# Fps: 63.98145069026009
# Detection of Image 2187
# Fps: 21.158988639344592
# Detection of Image 2188
# Fps: 63.973643670972955
# Detection of Image 2189
# Fps: 31.96098512557913
# Detection of Image 2190
# Fps: 32.052331534946276
# Detection of Image 2191
# Fps: 31.5496415757129
# Detection of Image 2192
# Fps: 32.00439513482992
# Detection of Image 2193
# Fps: 31.94005391492408
# Detection of Image 2194
# Fps: 31.53944024182997
# Detection of Image 2195
# Fps: 31.93081397119279
# Detection of Image 2196
# Fps: 32.03911024199462
# Detection of Image 2197
# Fps: 31.487586802297212
# Detection of Image 2198
# Fps: 21.332573811764107
# Detection of Image 2199
# Fps: 64.02344608621321
# Detection of Image 2200
# Fps: 21.158561685298036
# Detection of Image 2201
# Fps: 32.001220749692905
# Detection of Image 2202
# Fps: 21.30245361693915
# Detection of Image 2203
# Fps: 31.41683083030598
# Detection of Image 2204
# Fps: 32.00292995574546
# Detection of Image 2205
# Fps: 21.116165735286714
# Detection of Image 2206
# Fps: 63.99511756000061
# Detection of Image 2207
# Fps: 21.316419670264885
# Detection of Image 2208
# Fps: 32.05453614471643
# Detection of Image 2209
# Fps: 31.58313880815048
# Detection of Image 2210
# Fps: 64.01172089616018
# Detection of Image 2211
# Fps: 32.011478725434074
# Detection of Image 2212
# Fps: 21.073092304909665
# Detection of Image 2213
# Fps: 32.01929874115411
# Detection of Image 2214
# Fps: 64.01953721228402
# Detection of Image 2215
# Fps: 32.009524318301494
# Detection of Image 2216
# Fps: 32.086168910648716
# Detection of Image 2217
# Fps: 21.29899200203123
# Detection of Image 2218
# Fps: 64.02735543750381
# Detection of Image 2219
# Fps: 15.847895412982695
# Detection of Image 2220
# No Face Detected
# Fps: 16.854273739537163
# Detection of Image 2221
# No Face Detected
# Fps: 28.71650497401735
# Detection of Image 2222
# No Face Detected
# Fps: 6.3784226029803355
# Detection of Image 2223
# Fps: 61.838264997714774
# Detection of Image 2224
# No Face Detected
# Fps: 63.67451534058994
# Detection of Image 2225
# Fps: 32.012944687411746
# Detection of Image 2226
# Fps: 32.00439513482992
# Detection of Image 2227
# Fps: 31.60074739316497
# Detection of Image 2228
# Fps: 31.932029447815395
# Detection of Image 2229
# Fps: 31.511716490236886
# Detection of Image 2230
# Fps: 30.07639740418056
# Detection of Image 2231
# Fps: 28.518905834596897
# Detection of Image 2232
# Fps: 27.766550153585424
# Detection of Image 2233
# Fps: 32.00586044808009
# Detection of Image 2234
# Range: 0.7289612846029474fps - 236.1524688925173 fps
# Mean FPS: 33.49249600047584 fps

# %% [markdown]
# Camera Not Detected Situation: https://stackoverflow.com/questions/48049886/how-to-correctly-check-if-a-camera-is-available
